# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras import callbacks
from tensorflow.keras.layers import Dropout


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

# %%
# load the dataset as time series data
df = pd.read_csv('fifthClean.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
df.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_22096\705661990.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   df = pd.read_csv('fifthClean.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
#     Latitude  Longitude  Year  Month  Day  Hour  Minute  Second
# 0  51.513952  -0.085833  2019     12    1     2      17      49
# 1  51.511625  -0.081549  2019     12    2     3      14       4
# 2  51.509775  -0.085014  2019     12    2     4      51      16
# 3  51.517431  -0.082458  2019     12    3     9      48       8
# 4  51.516814  -0.081620  2019     12    4     2      53      26

# %%
# scale the data to be between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
df = pd.DataFrame(scaler.fit_transform(df))

# %%
# create time_steps to be used in the LSTM model
time_steps = 10
# create a function to create the time steps
def create_time_steps(df, time_steps):
    X = []
    y = []
    for i in range(len(df)-time_steps):
        X.append(df.iloc[i:(i+time_steps)].values)
        y.append(df.iloc[i+time_steps].values)
    return np.array(X), np.array(y)

# create the time steps
X, y = create_time_steps(df,time_steps)
print(X.shape)
print(y.shape)
# Out:
# (2084, 10, 8)
# (2084, 8)

# %%
print(X)
# Out:
# [[[0.29441565 0.18853324 0.         ... 0.08695652 0.28813559 0.83050847]
#   [0.27347659 0.20698134 0.         ... 0.13043478 0.23728814 0.06779661]
#   [0.25682972 0.19206008 0.         ... 0.17391304 0.86440678 0.27118644]
#   ...
#   [0.32796134 0.22018009 0.         ... 0.52173913 0.62711864 0.30508475]
#   [0.33319836 0.17832735 0.         ... 0.2173913  0.52542373 0.49152542]
#   [0.33319836 0.17832735 0.         ... 0.2173913  0.74576271 0.49152542]]
#
#  [[0.27347659 0.20698134 0.         ... 0.13043478 0.23728814 0.06779661]
#   [0.25682972 0.19206008 0.         ... 0.17391304 0.86440678 0.27118644]
#   [0.32572076 0.20306693 0.         ... 0.39130435 0.81355932 0.13559322]
#   ...
#   [0.33319836 0.17832735 0.         ... 0.2173913  0.52542373 0.49152542]
#   [0.33319836 0.17832735 0.         ... 0.2173913  0.74576271 0.49152542]
#   [0.32016881 0.2066756  0.         ... 0.26086957 0.22033898 0.13559322]]
#
#  [[0.25682972 0.19206008 0.         ... 0.17391304 0.86440678 0.27118644]
#   [0.32572076 0.20306693 0.         ... 0.39130435 0.81355932 0.13559322]
#   [0.32016881 0.2066756  0.         ... 0.08695652 0.89830508 0.44067797]
#   ...
#   [0.33319836 0.17832735 0.         ... 0.2173913  0.74576271 0.49152542]
#   [0.32016881 0.2066756  0.         ... 0.26086957 0.22033898 0.13559322]
#   [0.32213044 0.17295312 0.         ... 0.08695652 0.74576271 0.93220339]]
#
#  ...
#
#  [[0.29247202 0.14809296 1.         ... 0.69565217 0.01694915 0.15254237]
#   [0.29247202 0.14809296 1.         ... 0.69565217 0.15254237 0.83050847]
#   [0.2749973  0.1193184  1.         ... 0.17391304 0.08474576 0.55932203]
#   ...
#   [0.29152719 0.18773227 1.         ... 0.69565217 0.01694915 0.3220339 ]
#   [0.32399309 0.10136122 1.         ... 0.82608696 0.08474576 0.05084746]
#   [0.26956232 0.19113854 1.         ... 0.91304348 0.44067797 0.50847458]]
#
#  [[0.29247202 0.14809296 1.         ... 0.69565217 0.15254237 0.83050847]
#   [0.2749973  0.1193184  1.         ... 0.17391304 0.08474576 0.55932203]
#   [0.24366519 0.21736378 1.         ... 0.7826087  0.42372881 0.96610169]
#   ...
#   [0.32399309 0.10136122 1.         ... 0.82608696 0.08474576 0.05084746]
#   [0.26956232 0.19113854 1.         ... 0.91304348 0.44067797 0.50847458]
#   [0.28377965 0.04843273 1.         ... 0.91304348 0.71186441 0.10169492]]
#
#  [[0.2749973  0.1193184  1.         ... 0.17391304 0.08474576 0.55932203]
#   [0.24366519 0.21736378 1.         ... 0.7826087  0.42372881 0.96610169]
#   [0.32599071 0.17141578 1.         ... 0.2173913  0.93220339 0.37288136]
#   ...
#   [0.26956232 0.19113854 1.         ... 0.91304348 0.44067797 0.50847458]
#   [0.28377965 0.04843273 1.         ... 0.91304348 0.71186441 0.10169492]
#   [0.33498902 0.14000146 1.         ... 0.         0.77966102 0.77966102]]]

# %%
# reshape y to dim 3
y = y.reshape((y.shape[0], y.shape[1], 1))
print(X.shape, y.shape)
# Out:
# (2084, 10, 8) (2084, 8, 1)

# %%
# split into train and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (1667, 10, 8) (1667, 8, 1) (417, 10, 8) (417, 8, 1)

# %%
def plot_mae(history,range,title): #plot the mae
    plt.figure(figsize=(16,8))
    plt.title(title)
    plt.ylabel('Validation mae')
    plt.xlabel('Epochs')
    plt.plot(history['mae'][:range], label='Training mae', color='red')
    plt.plot(history['val_mae'][:range], label='Validation mae', color='green')
    # set x interval to 1
    plt.xticks(np.arange(0, range, 1.0))

    plt.legend(
        loc='upper right',
        shadow=True,
        fontsize='x-large'
    )
    plt.show()

# %%
model = models.Sequential()
model.add(layers.LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(layers.LSTM(32, return_sequences=True))
# model.add(layers.LSTM(512, return_sequences=True))
# model.add(layers.LSTM(256, return_sequences=True))
# model.add(layers.LSTM(128, return_sequences=True))
model.add(layers.LSTM(64))
model.add(layers.Dense(8))
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# fit model
history = model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_test, y_test),batch_size=512)

# plot the mae
plot_mae(history.history,100,'LSTM')
# Out:
# Epoch 1/100
# 4/4 [==============================] - 5s 284ms/step - loss: 0.2047 - mae: 0.3598 - val_loss: 0.0725 - val_mae: 0.2058
# Epoch 2/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0605 - mae: 0.1886 - val_loss: 0.0555 - val_mae: 0.1777
# Epoch 3/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0549 - mae: 0.1767 - val_loss: 0.0503 - val_mae: 0.1682
# Epoch 4/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0500 - mae: 0.1677 - val_loss: 0.0463 - val_mae: 0.1619
# Epoch 5/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0448 - mae: 0.1575 - val_loss: 0.0441 - val_mae: 0.1543
# Epoch 6/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0439 - mae: 0.1542 - val_loss: 0.0485 - val_mae: 0.1654
# Epoch 7/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0446 - mae: 0.1559 - val_loss: 0.0422 - val_mae: 0.1502
# Epoch 8/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0430 - mae: 0.1522 - val_loss: 0.0429 - val_mae: 0.1479
# Epoch 9/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0423 - mae: 0.1481 - val_loss: 0.0415 - val_mae: 0.1431
# Epoch 10/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0404 - mae: 0.1444 - val_loss: 0.0422 - val_mae: 0.1492
# Epoch 11/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0403 - mae: 0.1434 - val_loss: 0.0389 - val_mae: 0.1345
# Epoch 12/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0389 - mae: 0.1377 - val_loss: 0.0414 - val_mae: 0.1392
# Epoch 13/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0414 - mae: 0.1417 - val_loss: 0.0400 - val_mae: 0.1356
# Epoch 14/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0391 - mae: 0.1401 - val_loss: 0.0425 - val_mae: 0.1534
# Epoch 15/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0407 - mae: 0.1477 - val_loss: 0.0396 - val_mae: 0.1422
# Epoch 16/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0379 - mae: 0.1335 - val_loss: 0.0378 - val_mae: 0.1331
# Epoch 17/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0373 - mae: 0.1312 - val_loss: 0.0423 - val_mae: 0.1465
# Epoch 18/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0412 - mae: 0.1425 - val_loss: 0.0431 - val_mae: 0.1514
# Epoch 19/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0393 - mae: 0.1401 - val_loss: 0.0380 - val_mae: 0.1335
# Epoch 20/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0379 - mae: 0.1345 - val_loss: 0.0422 - val_mae: 0.1357
# Epoch 21/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0386 - mae: 0.1362 - val_loss: 0.0404 - val_mae: 0.1473
# Epoch 22/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0393 - mae: 0.1434 - val_loss: 0.0380 - val_mae: 0.1359
# Epoch 23/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0372 - mae: 0.1323 - val_loss: 0.0399 - val_mae: 0.1332
# Epoch 24/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0388 - mae: 0.1351 - val_loss: 0.0395 - val_mae: 0.1303
# Epoch 25/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0380 - mae: 0.1307 - val_loss: 0.0390 - val_mae: 0.1319
# Epoch 26/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0382 - mae: 0.1355 - val_loss: 0.0386 - val_mae: 0.1383
# Epoch 27/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0369 - mae: 0.1329 - val_loss: 0.0374 - val_mae: 0.1306
# Epoch 28/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0377 - mae: 0.1353 - val_loss: 0.0421 - val_mae: 0.1496
# Epoch 29/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0377 - mae: 0.1365 - val_loss: 0.0376 - val_mae: 0.1331
# Epoch 30/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0368 - mae: 0.1314 - val_loss: 0.0378 - val_mae: 0.1289
# Epoch 31/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0365 - mae: 0.1259 - val_loss: 0.0407 - val_mae: 0.1312
# Epoch 32/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0381 - mae: 0.1326 - val_loss: 0.0381 - val_mae: 0.1301
# Epoch 33/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0376 - mae: 0.1306 - val_loss: 0.0392 - val_mae: 0.1363
# Epoch 34/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0377 - mae: 0.1348 - val_loss: 0.0373 - val_mae: 0.1261
# Epoch 35/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0358 - mae: 0.1264 - val_loss: 0.0384 - val_mae: 0.1298
# Epoch 36/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0364 - mae: 0.1295 - val_loss: 0.0370 - val_mae: 0.1265
# Epoch 37/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0359 - mae: 0.1269 - val_loss: 0.0391 - val_mae: 0.1408
# Epoch 38/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0377 - mae: 0.1313 - val_loss: 0.0355 - val_mae: 0.1256
# Epoch 39/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0352 - mae: 0.1232 - val_loss: 0.0355 - val_mae: 0.1277
# Epoch 40/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0353 - mae: 0.1272 - val_loss: 0.0364 - val_mae: 0.1356
# Epoch 41/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0361 - mae: 0.1312 - val_loss: 0.0386 - val_mae: 0.1428
# Epoch 42/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0376 - mae: 0.1395 - val_loss: 0.0370 - val_mae: 0.1302
# Epoch 43/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.
100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0313 - mae: 0.1145 - val_loss: 0.0329 - val_mae: 0.1231
# Epoch 79/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0322 - mae: 0.1203 - val_loss: 0.0320 - val_mae: 0.1180
# Epoch 80/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0320 - mae: 0.1173 - val_loss: 0.0354 - val_mae: 0.1326
# Epoch 81/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0345 - mae: 0.1306 - val_loss: 0.0322 - val_mae: 0.1140
# Epoch 82/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0309 - mae: 0.1105 - val_loss: 0.0326 - val_mae: 0.1132
# Epoch 83/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0321 - mae: 0.1158 - val_loss: 0.0322 - val_mae: 0.1208
# Epoch 84/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0311 - mae: 0.1153 - val_loss: 0.0325 - val_mae: 0.1161
# Epoch 85/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0315 - mae: 0.1177 - val_loss: 0.0334 - val_mae: 0.1231
# Epoch 86/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0332 - mae: 0.1259 - val_loss: 0.0319 - val_mae: 0.1154
# Epoch 87/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0311 - mae: 0.1132 - val_loss: 0.0319 - val_mae: 0.1122
# Epoch 88/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0310 - mae: 0.1116 - val_loss: 0.0330 - val_mae: 0.1184
# Epoch 89/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0323 - mae: 0.1226 - val_loss: 0.0318 - val_mae: 0.1206
# Epoch 90/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0312 - mae: 0.1173 - val_loss: 0.0319 - val_mae: 0.1174
# Epoch 91/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0311 - mae: 0.1143 - val_loss: 0.0309 - val_mae: 0.1137
# Epoch 92/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0312 - mae: 0.1173 - val_loss: 0.0327 - val_mae: 0.1255
# Epoch 93/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0321 - mae: 0.1203 - val_loss: 0.0340 - val_mae: 0.1256
# Epoch 94/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0327 - mae: 0.1206 - val_loss: 0.0316 - val_mae: 0.1192
# Epoch 95/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0313 - mae: 0.1180 - val_loss: 0.0314 - val_mae: 0.1177
# Epoch 96/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0309 - mae: 0.1156 - val_loss: 0.0316 - val_mae: 0.1151
# Epoch 97/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0316 - mae: 0.1133 - val_loss: 0.0335 - val_mae: 0.1206
# Epoch 98/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0319 - mae: 0.1145 - val_loss: 0.0322 - val_mae: 0.1176
# Epoch 99/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0318 - mae: 0.1178 - val_loss: 0.0313 - val_mae: 0.1193
# Epoch 100/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0317 - mae: 0.1204 - val_loss: 0.0309 - val_mae: 0.1164

# %%
# predict the test set
y_pred = model.predict(X_test)
print(y_pred.shape)
# Out:
# 14/14 [==============================] - 1s 7ms/step
# (417, 8)

# %%
# print the first 10 predictions
print(y_pred[:1])
# reshape y_test to dim 2
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1]))
print(y_test.shape)
# Out:
# [[0.29191446 0.14489329 0.9921731  0.5380196  0.62768936 0.6087723
#   0.5192402  0.43732572]]
# (417, 8)

# %% [markdown]
# Conclusion: The prototype is working, but I was not able to invert the data back to its orginal form, so I can not use this approach for the final project. After some more indepth research and support from my ML lecturer. I was adivced to use a different approach, as currently, I am using multiple crimes topredict the next crime. This did not make much sence although the result shows positivily and strong connection between the crimes. I was advised to focus on one crime type and predict the next same crime. e.g. if the crime is burglary, then predict the next burglary. This will be the a better approach for the final project. Focusing on single crime type will also help to reduce the number of features and make the model more accurate and make it easier to interpret the results.
# My next steps:
# 1. data cleaning and feature engineering
# 2. data exploration and visualization before building the model
# 3. Ensure the time steps are correctlly scaled and inverted back to its original form for model evaluation
# 4. build a new model and evaluate the results
